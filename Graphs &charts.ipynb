# %%
pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in c:\users\komal\anaconda3\lib\site-packages (0.17.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.9.2 in c:\users\komal\anaconda3\lib\site-packages (from cufflinks) (1.26.4)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\komal\anaconda3\lib\site-packages (from cufflinks) (2.2.2)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\komal\anaconda3\lib\site-packages (from cufflinks) (5.24.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\komal\anaconda3\lib\site-packages (from cufflinks) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\komal\anaconda3\lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\komal\anaconda3\lib\site-packages (from cufflinks) (75.1.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\komal\anaconda3\lib\site-packages (from cufflinks) (8.27.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\komal\anaconda3\lib\site-packages (from cufflinks) (7.8.1)
# Requirement already satisfied: decorator in c:\users\komal\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\komal\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\komal\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\komal\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\komal\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\komal\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\komal\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.14.3)
# Requirement already satisfied: colorama in c:\users\komal\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\komal\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\komal\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\komal\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\komal\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\komal\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\komal\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\komal\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\komal\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (8.2.3)
# Requirement already satisfied: packaging in c:\users\komal\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (24.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\komal\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\komal\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\komal\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (7.2.2)
# Requirement already satisfied: executing in c:\users\komal\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\komal\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\komal\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\komal\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\komal\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\komal\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\komal\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\komal\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (6.4.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\komal\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\komal\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\komal\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\komal\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\komal\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\komal\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\komal\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\komal\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\komal\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\komal\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\komal\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (21.2.0)
# Requirement already satisfied: certifi in c:\users\komal\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\komal\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\komal\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\komal\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\komal\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (1.6.0)
# Requirement already satisfied: psutil in c:\users\komal\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\komal\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\komal\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\komal\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\komal\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\komal\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\komal\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\komal\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\komal\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\komal\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\komal\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\komal\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\komal\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\komal\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\komal\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\komal\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\komal\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\komal\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\komal\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.2.3)
# Requirement already satisfied: webencodings in c:\users\komal\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\komal\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\komal\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\komal\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.1)
# Requirement already satisfied: uri-template in c:\users\komal\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\komal\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\komal\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\komal\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.5)
# Requirement already satisfied: pycparser in c:\users\komal\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\komal\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->cufflinks) (1.2.3)

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import cufflinks as cf

# %%
np.random.random(100)
# Out:
# array([8.69173170e-01, 2.19172797e-01, 8.99910434e-01, 9.78949517e-01,
#        6.65342517e-01, 8.38867168e-01, 3.24359204e-01, 3.71472602e-01,
#        7.15346798e-02, 3.97458722e-01, 6.91748544e-01, 9.54568977e-01,
#        9.02371490e-02, 4.36470901e-01, 2.97694059e-01, 9.05561394e-01,
#        5.12139862e-01, 7.26483268e-01, 8.84287084e-01, 6.74412601e-01,
#        5.50440800e-01, 8.33908920e-01, 6.53357251e-01, 1.29186605e-01,
#        2.79708438e-01, 8.70098419e-01, 1.66122708e-01, 5.75768937e-01,
#        9.76315213e-01, 3.16478120e-01, 9.54501174e-01, 4.65804138e-01,
#        1.11178921e-01, 2.54459757e-01, 3.55159523e-01, 3.24580600e-01,
#        3.42909980e-01, 6.59641154e-01, 1.85444532e-02, 4.71360391e-01,
#        7.94550268e-01, 8.79389135e-01, 9.79989581e-01, 8.41398394e-02,
#        1.59917973e-02, 3.22775128e-01, 8.62724405e-01, 7.66383578e-01,
#        7.77104673e-01, 5.15587820e-01, 4.41935254e-01, 2.96626346e-01,
#        7.73062546e-01, 8.76558970e-01, 6.18254777e-01, 5.35645411e-01,
#        1.92212831e-01, 2.13635921e-05, 2.47499154e-01, 2.95330900e-01,
#        8.74404443e-01, 6.01568363e-01, 3.94865648e-01, 7.30236827e-01,
#        5.32052580e-01, 9.43775825e-01, 7.78028160e-01, 7.77424558e-01,
#        5.03877169e-02, 6.85951841e-01, 4.58835739e-01, 2.01948010e-01,
#        8.94322217e-01, 8.81739688e-01, 6.41108604e-01, 3.86755730e-01,
#        8.62362053e-01, 7.99217811e-01, 7.85096331e-01, 6.24922087e-01,
#        9.92110345e-01, 5.75943215e-01, 6.90712631e-01, 2.72733819e-02,
#        6.94363366e-01, 4.86357552e-01, 3.69613697e-01, 2.68460060e-01,
#        5.86764724e-02, 1.51651054e-01, 3.35726855e-01, 4.23264929e-01,
#        3.54486707e-01, 8.83496303e-01, 2.26134516e-02, 6.02520080e-01,
#        7.33425931e-02, 6.46570183e-01, 9.51072623e-01, 2.10086916e-01])

# %%
a = pd.DataFrame(np.random.random(100))

# %%
a
# Out:
#            0
# 0   0.645219
# 1   0.694096
# 2   0.061411
# 3   0.990443
# 4   0.844039
# ..       ...
# 95  0.820537
# 96  0.103005
# 97  0.276994
# 98  0.558971
# 99  0.303145
#
# [100 rows x 1 columns]

# %%
b = pd.DataFrame(np.random.random(100))

# %%
b
# Out:
#            0
# 0   0.765628
# 1   0.360962
# 2   0.083549
# 3   0.649755
# 4   0.819670
# ..       ...
# 95  0.410960
# 96  0.837317
# 97  0.293410
# 98  0.643596
# 99  0.761007
#
# [100 rows x 1 columns]

# %%
c = pd.DataFrame(np.random.random(100))

# %%
c
# Out:
#            0
# 0   0.708895
# 1   0.030668
# 2   0.372310
# 3   0.525934
# 4   0.557949
# ..       ...
# 95  0.870875
# 96  0.451136
# 97  0.956077
# 98  0.158595
# 99  0.849488
#
# [100 rows x 1 columns]

# %%
df= pd.concat([a,b,c],axis=1)

# %%
df
# Out:
#            0         0         0
# 0   0.645219  0.765628  0.708895
# 1   0.694096  0.360962  0.030668
# 2   0.061411  0.083549  0.372310
# 3   0.990443  0.649755  0.525934
# 4   0.844039  0.819670  0.557949
# ..       ...       ...       ...
# 95  0.820537  0.410960  0.870875
# 96  0.103005  0.837317  0.451136
# 97  0.276994  0.293410  0.956077
# 98  0.558971  0.643596  0.158595
# 99  0.303145  0.761007  0.849488
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#           0         0         0
# 0  0.645219  0.765628  0.708895
# 1  0.694096  0.360962  0.030668
# 2  0.061411  0.083549  0.372310
# 3  0.990443  0.649755  0.525934
# 4  0.844039  0.819670  0.557949

# %%
df.plot()
# Out:
# <Axes: >

# %%
df = pd.read_csv('titanic (1).csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.lineplot(data=df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
d = [1,2,3,4,5]

# %%
sns.lineplot(data=d)
# Out:
# <Axes: >

# %%
sns.barplot(data=df, x = 'Survived', y='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='Sex'>
